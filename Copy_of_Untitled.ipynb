# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishwarya-2007/Internship-/blob/main/Copy_of_Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="ishu"
age=19
cgpa=8.9
placed=True
print("student name:",name)
print("age",age)
print("cgpa",cgpa)
print("placed",placed)
print(type(name))
print(type(age))
print(type(cgpa))
print(type(placed))


student name: ishu
age 19
cgpa 8.9
placed True
<class 'str'>
<class 'int'>
<class 'float'>
<class 'bool'>
list

In [ ]:

name=["ishu","joy","dharshu"]
marks=[100,90,75]
print(name[0])
print(marks[0])
print(len(marks))
name.append("geethu")
print(name)


ishu
100
3
['ishu', 'joy', 'dharshu', 'geethu']
tuple

In [ ]:

days=("monday","tuesday","wednesday","thursday","friday")
print(days)


('monday', 'tuesday', 'wednesday', 'thursday', 'friday')
january
dictionary

In [ ]:

student={
    "name":"dharshu",
    "age":"19"}
print(student)

{'name': 'dharshu', 'age': '19'}
