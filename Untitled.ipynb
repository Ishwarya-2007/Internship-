# %% [markdown]
# <a href="https://colab.research.google.com/github/Ishwarya-2007/Internship-/blob/main/Untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name="ishwarya"

age = 19

CGPA=7.6

Placed=True

print("Student name", name)

print ("Age:", age)

print("CGPA:", CGPA)

print("Placed", Placed)

print (type (name))

Student name ishwarya
Age: 19
CGPA: 7.6
Placed True
<class 'str'>
